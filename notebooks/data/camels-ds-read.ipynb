# %%
import os
import torch
import joblib
import random

import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import torch.utils.data as data

# %%
data_path = '/data/camels/datasets/'
scaler_path = '/data/camels/scalers/'

# %%
station_list = os.listdir(data_path+'train')
station_id = random.choice(station_list)

# %%
X_train = torch.load(os.path.join(data_path, 'train', station_id, 'X_train.pt'))
y_train = torch.load(os.path.join(data_path, 'train', station_id, 'y_train.pt'))
t_train = torch.load(os.path.join(data_path, 'train', station_id, 't_train.pt'))

# %%
X_train.shape
# Out:
# torch.Size([8629, 7, 5])

# %%
X_train[0]
# Out:
# tensor([[ 0.8341,  0.2003,  1.4733,  1.7501,  2.1315],
#         [-0.3121,  1.3840,  1.6327,  1.8613,  2.2250],
#         [ 0.0640,  0.5257,  1.3025,  2.0131,  2.7117],
#         [ 0.9400,  0.1256,  0.7647,  1.8428,  3.1377],
#         [ 0.7869,  0.6601,  1.1027,  1.8436,  2.6886],
#         [-0.2171, -0.6566,  0.9908,  1.6739,  1.9515],
#         [-0.3215,  0.6274,  1.7577,  1.5020,  0.9641]])

# %%
y_train[0]
# Out:
# tensor([-0.2108])

# %%
x_scaler = joblib.load(os.path.join(scaler_path, 'x_scaler.save'))
y_scaler = joblib.load(os.path.join(scaler_path, 'y_scaler.save'))

# %%
y_scaler.inverse_transform(y_train)
# Out:
# array([[0.0738332 ],
#        [0.06484834],
#        [0.05718431],
#        ...,
#        [0.01575271],
#        [0.01602928],
#        [0.01632299]])

# %%
date_train = pd.to_datetime(t_train, unit='s')

# %%
fig, ax = plt.subplots(figsize=(20, 5))

ax.plot(date_train, y_train, color='black')
