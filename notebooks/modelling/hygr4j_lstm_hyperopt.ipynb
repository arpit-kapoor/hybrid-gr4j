# %%
import optuna
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as torchdata
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import datetime as dt

import os
import sys

from sklearn.model_selection import train_test_split
from tqdm import tqdm
from optuna.trial import TrialState

sys.path.append("/project")

from model.hydro.gr4j_prod import ProductionStorage
from model.utils.training import EarlyStopper
from model.utils.evaluation import evaluate
from model.optim.pso_np import PSO
from data.utils import read_dataset_from_file, get_station_list
from model.ml.lstm import LSTM
from model.utils.evaluation import evaluate

# %%
data_dir = '/data/camels/aus/'
sub_dir = 'no-scale'
station_id = '401009'
run_dir = '/project/results/hygr4j'

N_EPOCHS = 50
BATCH_SIZE = 256

INPUT_DIM = 9
X1 = 1047.4872337246686

# %%
def create_sequence(X, y, window_size):

        assert window_size is not None, "Window size cannot be NoneType."

        # Create empyty sequences
        Xs, ys = [], []

        # Add sequences to Xs and ys
        for i in range(len(X)-window_size):
            Xs.append(X[i: (i + window_size)])
            ys.append(y[i + window_size-1])

        Xs, ys = torch.stack(Xs), torch.stack(ys)

        return Xs, ys

# %%
print(f"Reading data for station_id: {station_id}")
train_ds, test_ds = read_dataset_from_file(data_dir, 
                                        sub_dir, 
                                        station_id=station_id)

# Get tensors from dataset
t_train, X_train, y_train = train_ds.tensors
t_test, X_test, y_test = test_ds.tensors

# Scale input tensor
X_train = torch.nan_to_num(X_train)
X_test = torch.nan_to_num(X_test)

# Scale labels
y_mu = y_train.mean(dim=0)
y_sigma = y_train.std(dim=0)
y_train = (y_train - y_mu)/y_sigma
y_test = (y_test - y_mu)/y_sigma

# Production storage
prod_store = ProductionStorage(x1=X1)

# Prod storage output
prod_out_train = prod_store(X_train, include_x=True)[0]
X_train, y_train = create_sequence(prod_out_train, y_train, window_size=4)

prod_out_test = prod_store(X_test, include_x=True)[0]
X_test, y_test = create_sequence(prod_out_test, y_test, window_size=4)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                  test_size=0.25, shuffle=False)

# Create train dataset and loader
train_ds = torchdata.TensorDataset(X_train, y_train)
train_dl = torchdata.DataLoader(train_ds,
                                batch_size=BATCH_SIZE,
                                shuffle=True)

# Create validation dataset and loader
val_ds = torchdata.TensorDataset(X_val, y_val)
val_dl = torchdata.DataLoader(val_ds,
                              batch_size=BATCH_SIZE,
                              shuffle=True)

test_ds = torchdata.TensorDataset(X_test, y_test)
test_dl = torchdata.DataLoader(test_ds,
                              batch_size=BATCH_SIZE,
                              shuffle=False)
# Out:
# Reading data for station_id: 401009

# %%
if not os.path.exists(run_dir):
    os.makedirs(run_dir)

plot_dir = os.path.join(run_dir, 'plots')
if not os.path.exists(plot_dir):
    os.makedirs(plot_dir)

# %%
def define_model(trial):
    n_layers = trial.suggest_int("n_layers", 1, 3)
    hidden_dim = trial.suggest_int("hidden_dim", 16, 64, step=16)
    p = trial.suggest_float("dropout", 0.2, 0.5)
    
    model = LSTM(input_dim=INPUT_DIM,
            hidden_dim=hidden_dim,
            output_dim=1,
            n_layers=n_layers,
            dropout=p)

    return model

# %%
def val_step(model, dl, loss_fn):
    loss_val = 0.
    model.eval()
    for j, (X, y) in enumerate(dl, start=1):
        y_hat = model(X)
        loss_val += loss_fn(y, y_hat)
    return (loss_val/j).detach()


def train_step(model, dl, loss_fn, opt):
    total_loss = 0.
    model.train()
    for i, (X, y) in enumerate(dl, start=1):
        opt.zero_grad()
        y_hat = model(X)
        loss_val = loss_fn(y, y_hat)
        total_loss += loss_val
        loss_val.backward()
        opt.step()
    return (total_loss/i).detach()

def evaluate_preds(model, ds, batch_size, x_scaler=None, y_scaler=None, plot=True):
    # Evaluate on train data
    model.eval()
    dl = torchdata.DataLoader(ds, 
                              batch_size=batch_size,
                              shuffle=False)

    # Empty list to store batch-wise tensors
    P = []
    ET = []
    Q = []
    Q_hat = []

    for i, (X, y) in enumerate(dl, start=1):
        
        y_hat = model(X)

        Q.append((y*y_sigma+y_mu).detach().numpy())
        Q_hat.append((y_hat*y_sigma+y_mu).detach().numpy())
        
        X_inv = X[:, -1]*prod_store.sigma+prod_store.mu
        
        P.append((X_inv[:, 0]).detach().numpy())
        ET.append((X_inv[:, 1]).detach().numpy())
    
    P = np.concatenate(P, axis=0)
    ET = np.concatenate(ET, axis=0)
    Q = np.concatenate(Q, axis=0).flatten()
    Q_hat = np.clip(np.concatenate(Q_hat, axis=0).flatten(), 0, None)


    return evaluate(P, ET, Q, Q_hat, plot=plot)

# %%
def objective(trial, return_model=False):
    # Generate the model.
    model = define_model(trial)

    # Generate the optimizers.
    optimizer_name = trial.suggest_categorical("optimizer", ["Adam", "RMSprop", "SGD"])
    lr = trial.suggest_float("lr", 1e-4, 1e-2, log=True)
    opt = getattr(optim, optimizer_name)(model.parameters(), lr=lr)

    # Loss function
    loss_fn = nn.MSELoss()

    # Early stopping
    early_stopper = EarlyStopper(patience=10, min_delta=0.01)

    pbar = range(1, N_EPOCHS+1)

    for epoch in pbar:

        # Train step
        train_loss = train_step(model, train_dl, loss_fn, opt)

        # Validation step
        val_nse, _ = evaluate_preds(model, val_dl.dataset, 
                                    batch_size=BATCH_SIZE, plot=False)

        trial.report(val_nse, epoch)

        # Handle pruning based on the intermediate value.
        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()
    
    if return_model:
        return model
    return val_nse

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100, timeout=600)

pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

print("Study statistics: ")
print("  Number of finished trials: ", len(study.trials))
print("  Number of pruned trials: ", len(pruned_trials))
print("  Number of complete trials: ", len(complete_trials))

print("Best trial:")
trial = study.best_trial

print("  Value: ", trial.value)

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2023-01-31 12:20:57,604] A new study created in memory with name: no-name-6f80a354-113d-4888-9023-e203beb8d092
# [I 2023-01-31 12:21:03,153] Trial 0 finished with value: 0.6987407505512238 and parameters: {'n_layers': 1, 'hidden_dim': 16, 'dropout': 0.4851177777682522, 'optimizer': 'Adam', 'lr': 0.00424031775255147}. Best is trial 0 with value: 0.6987407505512238.
# [I 2023-01-31 12:21:20,788] Trial 1 finished with value: -0.3371555805206299 and parameters: {'n_layers': 3, 'hidden_dim': 64, 'dropout': 0.32473685832286187, 'optimizer': 'SGD', 'lr': 0.00433133767283246}. Best is trial 0 with value: 0.6987407505512238.
# [I 2023-01-31 12:21:31,343] Trial 2 finished with value: -1.2060906887054443 and parameters: {'n_layers': 2, 'hidden_dim': 32, 'dropout': 0.2153015653405369, 'optimizer': 'RMSprop', 'lr': 0.00013010388078537642}. Best is trial 0 with value: 0.6987407505512238.
# [I 2023-01-31 12:21:38,492] Trial 3 finished with value: -1.0297472476959229 and parameters: {'n_layers': 1, 'hidden_dim': 48, 'dropout': 0.2199695682305203, 'optimizer': 'Adam', 'lr': 0.0005834814468993586}. Best is trial 0 with value: 0.6987407505512238.
# [I 2023-01-31 12:21:44,857] Trial 4 finished with value: 0.5626001954078674 and parameters: {'n_layers': 2, 'hidden_dim': 16, 'dropout': 0.43407063086093833, 'optimizer': 'Adam', 'lr': 0.0021452995700231496}. Best is trial 0 with value: 0.6987407505512238.
# [I 2023-01-31 12:21:53,043] Trial 5 finished with value: 0.4892714023590088 and parameters: {'n_layers': 2, 'hidden_dim': 32, 'dropout': 0.43139089283521703, 'optimizer': 'Adam', 'lr': 0.0011127377525446934}. Best is trial 0 with value: 0.6987407505512238.
# [I 2023-01-31 12:21:53,366] Trial 6 pruned.
# [I 2023-01-31 12:22:02,860] Trial 7 finished with value: 0.21628594398498535 and parameters: {'n_layers': 2, 'hidden_dim': 48, 'dropout': 0.27306675142627146, 'optimizer': 'RMSprop', 'lr': 0.004360379366541008}. Best is trial 0 with value: 0.6987407505512238.
# [I 2023-01-31 12:22:03,125] Trial 8 pruned.
# [I 2023-01-31 12:22:03,336] Trial 9 pruned.
# [I 2023-01-31 12:22:04,806] Trial 10 pruned.
# [I 2023-01-31 12:22:06,585] Trial 11 pruned.
# [I 2023-01-31 12:22:09,836] Trial 12 pruned.
# [I 2023-01-31 12:22:14,487] Trial 13 finished with value: 0.6949784159660339 and parameters: {'n_layers': 1, 'hidden_dim': 16, 'dropout': 0.4472073683347109, 'optimizer': 'Adam', 'lr': 0.0024371861674021946}. Best is trial 0 with value: 0.6987407505512238.
# [I 2023-01-31 12:22:19,151] Trial 14 finished with value: 0.5773350298404694 and parameters: {'n_layers': 1, 'hidden_dim': 16, 'dropout': 0.4644490221729306, 'optimizer': 'Adam', 'lr': 0.0022775595022539283}. Best is trial 0 with value: 0.6987407505512238.
# [I 2023-01-31 12:22:25,188] Trial 15 finished with value: 0.3809582591056824 and parameters: {'n_layers': 1, 'hidden_dim': 32, 'dropout': 0.4636145791548353, 'optimizer': 'Adam', 'lr': 0.008315671803524088}. Best is trial 0 with value: 0.6987407505512238.
# [I 2023-01-31 12:22:26,041] Trial 16 pruned.
# [I 2023-01-31 12:22:26,158] Trial 17 pruned.
# [I 2023-01-31 12:22:30,773] Trial 18 finished with value: 0.13598036766052246 and parameters: {'n_layers': 1, 'hidden_dim': 16, 'dropout': 0.473382575669803, 'optimizer': 'Adam', 'lr': 0.0049169920518604745}. Best is trial 0 with value: 0.6987407505512238.
# [I 2023-01-31 12:22:30,937] Trial 19 pruned.
# [I 2023-01-31 12:22:31,051] Trial 20 pruned.
# [I 2023-01-31 12:22:31,161] Trial 21 pruned.
# [I 2023-01-31 12:22:32,153] Trial 22 pruned.
# [I 2023-01-31 12:22:32,266] Trial 23 pruned.
# [I 2023-01-31 12:22:32,638] Trial 24 pruned.
# [I 2023-01-31 12:22:33,789] Trial 25 pruned.
# [I 2023-01-31 12:22:33,918] Trial 26 pruned.
# [I 2023-01-31 12:22:40,902] Trial 27 finished with value: 0.25462621450424194 and parameters: {'n_layers': 2, 'hidden_dim': 16, 'dropout': 0.4822096763626314, 'optimizer': 'Adam', 'lr': 0.004117281506874592}. Best is trial 0 with value: 0.6987407505512238.
# [I 2023-01-31 12:22:45,670] Trial 28 finished with value: 0.21861708164215088 and parameters: {'n_layers': 1, 'hidden_dim': 16, 'dropout': 0.41471983923603895, 'optimizer': 'RMSprop', 'lr': 0.005967440618401612}. Best is trial 0 with value: 0.6987407505512238.
# [I 2023-01-31 12:22:45,955] Trial 29 pruned.
# [I 2023-01-31 12:22:46,111] Trial 30 pruned.
# [I 2023-01-31 12:22:47,528] Trial 31 pruned.
# [I 2023-01-31 12:22:48,751] Trial 32 pruned.
# [I 2023-01-31 12:22:56,703] Trial 33 finished with value: 0.40948575735092163 and parameters: {'n_layers': 3, 'hidden_dim': 16, 'dropout': 0.4791045584777236, 'optimizer': 'Adam', 'lr': 0.0020969663201799707}. Best is trial 0 with value: 0.6987407505512238.
# [I 2023-01-31 12:22:56,884] Trial 34 pruned.
# [I 2023-01-31 12:22:59,949] Trial 35 pruned.
# [I 2023-01-31 12:23:00,079] Trial 36 pruned.
# [I 2023-01-31 12:23:06,283] Trial 37 finished with value: 0.547346293926239 and parameters: {'n_layers': 2, 'hidden_dim': 16, 'dropout': 0.4064830937970434, 'optimizer': 'Adam', 'lr': 0.0019488063442593827}. Best is trial 0 with value: 0.6987407505512238.
# [I 2023-01-31 12:23:06,587] Trial 38 pruned.
# [I 2023-01-31 12:23:06,757] Trial 39 pruned.
# [I 2023-01-31 12:23:08,931] Trial 40 pruned.
# [I 2023-01-31 12:23:09,067] Trial 41 pruned.
# [I 2023-01-31 12:23:09,207] Trial 42 pruned.
# [I 2023-01-31 12:23:09,343] Trial 43 pruned.
# [I 2023-01-31 12:23:17,327] Trial 44 finished with value: 0.6584572792053223 and parameters: {'n_layers': 3, 'hidden_dim': 16, 'dropout': 0.3892337875226379, 'optimizer': 'Adam', 'lr': 0.0019353936534345006}. Best is trial 0 with value: 0.6987407505512238.
# [I 2023-01-31 12:23:25,205] Trial 45 finished with value: 0.5966148674488068 and parameters: {'n_layers': 3, 'hidden_dim': 16, 'dropout': 0.3785189689913933, 'optimizer': 'Adam', 'lr': 0.002942331835374139}. Best is trial 0 with value: 0.6987407505512238.
# [I 2023-01-31 12:23:25,372] Trial 46 pruned.
# [I 2023-01-31 12:23:35,483] Trial 47 finished with value: 0.21529406309127808 and parameters: {'n_layers': 3, 'hidden_dim': 32, 'dropout': 0.37005532703019806, 'optimizer': 'RMSprop', 'lr': 0.002609439260736058}. Best is trial 0 with value: 0.6987407505512238.
# [I 2023-01-31 12:23:35,793] Trial 48 pruned.
# [I 2023-01-31 12:23:37,322] Trial 49 pruned.
# [I 2023-01-31 12:23:37,505] Trial 50 pruned.
# [I 2023-01-31 12:23:37,693] Trial 51 pruned.
# [I 2023-01-31 12:23:37,812] Trial 52 pruned.
# [I 2023-01-31 12:23:45,993] Trial 53 finished with value: 0.49585211277008057 and parameters: {'n_layers': 3, 'hidden_dim': 16, 'dropout': 0.4346828302678605, 'optimizer': 'Adam', 'lr': 0.001995627259606526}. Best is trial 0 with value: 0.6987407505512238.
# [I 2023-01-31 12:23:47,071] Trial 54 pruned.
# [I 2023-01-31 12:23:47,185] Trial 55 pruned.
# [I 2023-01-31 12:23:50,530] Trial 56 pruned.
# [I 2023-01-31 12:23:50,674] Trial 57 pruned.
# [I 2023-01-31 12:23:50,787] Trial 58 pruned.
# [I 2023-01-31 12:23:50,889] Trial 59 pruned.
# [I 2023-01-31 12:23:51,099] Trial 60 pruned.
# [I 2023-01-31 12:23:51,255] Trial 61 pruned.
# [I 2023-01-31 12:23:51,397] Trial 62 pruned.
# [I 2023-01-31 12:23:51,559] Trial 63 pruned.
# [I 2023-01-31 12:23:51,701] Trial 64 pruned.
# [I 2023-01-31 12:23:51,809] Trial 65 pruned.
# [I 2023-01-31 12:23:51,916] Trial 66 pruned.
# [I 2023-01-31 12:23:52,054] Trial 67 pruned.
# [I 2023-01-31 12:23:52,198] Trial 68 pruned.
# [I 2023-01-31 12:23:52,300] Trial 69 pruned.
# [I 2023-01-31 12:23:52,475] Trial 70 pruned.
# [I 2023-01-31 12:23:52,647] Trial 71 pruned.
# [I 2023-01-31 12:24:00,720] Trial 72 finished with value: 0.19977879524230957 and parameters: {'n_layers': 3, 'hidden_dim': 16, 'dropout': 0.40128452382640767, 'optimizer': 'Adam', 'lr': 0.002254386883689371}. Best is trial 0 with value: 0.6987407505512238.
# [I 2023-01-31 12:24:01,510] Trial 73 pruned.
# [I 2023-01-31 12:24:01,681] Trial 74 pruned.
# [I 2023-01-31 12:24:01,871] Trial 75 pruned.
# [I 2023-01-31 12:24:02,040] Trial 76 pruned.
# [I 2023-01-31 12:24:02,167] Trial 77 pruned.
# [I 2023-01-31 12:24:02,342] Trial 78 pruned.
# [I 2023-01-31 12:24:03,283] Trial 79 pruned.
# [I 2023-01-31 12:24:07,947] Trial 80 finished with value: 0.7074524760246277 and parameters: {'n_layers': 1, 'hidden_dim': 16, 'dropout': 0.38312865986981354, 'optimizer': 'Adam', 'lr': 0.004300157360686417}. Best is trial 80 with value: 0.7074524760246277.
# [I 2023-01-31 12:24:08,055] Trial 81 pruned.
# [I 2023-01-31 12:24:08,163] Trial 82 pruned.
# [I 2023-01-31 12:24:08,316] Trial 83 pruned.
# [I 2023-01-31 12:24:08,446] Trial 84 pruned.
# [I 2023-01-31 12:24:08,572] Trial 85 pruned.
# [I 2023-01-31 12:24:08,678] Trial 86 pruned.
# [I 2023-01-31 12:24:08,791] Trial 87 pruned.
# [I 2023-01-31 12:24:09,163] Trial 88 pruned.
# [I 2023-01-31 12:24:09,279] Trial 89 pruned.
# [I 2023-01-31 12:24:09,485] Trial 90 pruned.
# [I 2023-01-31 12:24:09,662] Trial 91 pruned.
# [I 2023-01-31 12:24:09,803] Trial 92 pruned.
# [I 2023-01-31 12:24:10,613] Trial 93 pruned.
# [I 2023-01-31 12:24:10,764] Trial 94 pruned.
# [I 2023-01-31 12:24:10,947] Trial 95 pruned.
# [I 2023-01-31 12:24:11,137] Trial 96 pruned.
# [I 2023-01-31 12:24:11,358] Trial 97 pruned.
# [I 2023-01-31 12:24:11,473] Trial 98 pruned.
# [I 2023-01-31 12:24:11,613] Trial 99 pruned.
# Study statistics:
#   Number of finished trials:  100
#   Number of pruned trials:  79
#   Number of complete trials:  21
# Best trial:
#   Value:  0.7074524760246277
#   Params:
#     n_layers: 1
#     hidden_dim: 16
#     dropout: 0.38312865986981354
#     optimizer: Adam
#     lr: 0.004300157360686417

# %%
def train_model(trial):
    
    # Generate the model.
    model = define_model(trial)

    # Generate the optimizers.
    optimizer_name = trial.suggest_categorical("optimizer", ["Adam", "RMSprop", "SGD"])
    lr = trial.suggest_float("lr", 1e-5, 1e-2, log=True)
    opt = getattr(optim, optimizer_name)(model.parameters(), lr=lr)

    # Loss function
    loss_fn = nn.MSELoss()

    # Early stopping
    early_stopper = EarlyStopper(patience=10, min_delta=0.01)

    pbar = tqdm(range(1, N_EPOCHS+1))

    for epoch in pbar:

        # Train step
        train_loss = train_step(model, train_dl, loss_fn, opt)

        # Train step
        val_loss = val_step(model, val_dl, loss_fn)

        pbar.set_description(f"""Epoch {epoch} loss: {train_loss.numpy():.4f} val_loss: {val_loss.numpy():.4f}""")

        if early_stopper.early_stop(val_loss):
            break
    
    return model

# %%
N_EPOCHS = 200
model = train_model(trial)
# Out:
# Epoch 45 loss: 0.2521 val_loss: 0.1319:  22%|██▏       | 44/200 [00:04<00:16,  9.51it/s]

# %%
evaluate_preds(model, val_ds, batch_size=BATCH_SIZE)
# Out:
# (0.6547927260398865, 0.7433798637262281, <Figure size 1600x600 with 1 Axes>)

# %%
evaluate_preds(model, test_ds, batch_size=BATCH_SIZE)
# Out:
# (0.44793570041656494, 0.6443032033327447, <Figure size 1600x600 with 1 Axes>)
